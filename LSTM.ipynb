# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusalb/RNNs-for-stock-price-prediction/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from sklearn.metrics import mean_absolute_error
from torch.utils.data import DataLoader

# %%
dataset = pd.read_csv("google.csv")
dataset
# Out:
#             Date         High          Low         Open        Close  \
# 0     2004-08-19    51.835709    47.800831    49.813290    49.982655
# 1     2004-08-20    54.336334    50.062355    50.316402    53.952770
# 2     2004-08-23    56.528118    54.321388    55.168217    54.495735
# 3     2004-08-24    55.591629    51.591621    55.412300    52.239197
# 4     2004-08-25    53.798351    51.746044    52.284027    52.802086
# ...          ...          ...          ...          ...          ...
# 4312  2021-10-05  2747.239990  2680.000000  2680.000000  2723.540039
# 4313  2021-10-06  2757.040039  2689.729980  2692.510010  2747.080078
# 4314  2021-10-07  2803.089111  2771.260010  2777.260010  2783.709961
# 4315  2021-10-08  2806.340088  2788.586914  2798.120117  2801.120117
# 4316  2021-10-11  2815.272949  2776.129883  2796.000000  2776.949951
#
#           Volume    Adj Close
# 0     44871361.0    49.982655
# 1     22942874.0    53.952770
# 2     18342897.0    54.495735
# 3     15319808.0    52.239197
# 4      9232276.0    52.802086
# ...          ...          ...
# 4312   1206300.0  2723.540039
# 4313    988200.0  2747.080078
# 4314    912500.0  2783.709961
# 4315    946200.0  2801.120117
# 4316    828700.0  2776.949951
#
# [4317 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4317 entries, 0 to 4316
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4317 non-null   object
#  1   High       4317 non-null   float64
#  2   Low        4317 non-null   float64
#  3   Open       4317 non-null   float64
#  4   Close      4317 non-null   float64
#  5   Volume     4317 non-null   float64
#  6   Adj Close  4317 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 236.2+ KB

# %% [markdown]
# Date: The date the stock was traded.
# High: The highest price of the stock on a given day.
# Low: The lowest price of a stock on a given day.
# Open: The starting price of a specific day, that is, the opening price of the trading day.
# Close: The closing price of a specific day, that is, the last price of the trading day.
# Volume: The amount of shares traded on a given day.
# Adj Close: Adjusted closing price, the closing price of the stock calculated taking into account dividend payments and other adjustments. This more accurately reflects price changes.

# %%
dataset.head()
# Out:
#          Date       High        Low       Open      Close      Volume  \
# 0  2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0
# 1  2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0
# 2  2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0
# 3  2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0
# 4  2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0
#
#    Adj Close
# 0  49.982655
# 1  53.952770
# 2  54.495735
# 3  52.239197
# 4  52.802086

# %%
dataset.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4317.000000  4317.000000  4317.000000  4317.000000  4.317000e+03
# mean    639.682936   627.615621   633.603748   633.852357  6.523837e+06
# std     561.783142   552.069438   556.527532   557.255541  7.830526e+06
# min      50.680038    47.800831    49.409801    49.818268  7.922000e+03
# 25%     247.507278   241.469910   244.832306   244.334183  1.593563e+06
# 50%     401.988251   395.168823   399.004425   398.561096  3.851583e+06
# 75%     933.440002   923.030029   929.059998   928.799988  8.268878e+06
# max    2936.409912  2912.290039  2918.989990  2916.840088  8.254163e+07
#
#          Adj Close
# count  4317.000000
# mean    633.852357
# std     557.255541
# min      49.818268
# 25%     244.334183
# 50%     398.561096
# 75%     928.799988
# max    2916.840088

# %%
dataset.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])
plt.plot(dataset['Date'], dataset['Close'])

# %%
dataset.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0
# 1 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0
# 2 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0
# 3 2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0
# 4 2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0
#
#    Adj Close
# 0  49.982655
# 1  53.952770
# 2  54.495735
# 3  52.239197
# 4  52.802086

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)

    df.set_index('Date', inplace=True)

    for i in range(1, n_steps + 1):
        df[f'Close(t-{i})'] = df['Close'].shift(i)
    df.dropna(inplace=True)
    return df[['Close'] + [f'Close(t-{i})' for i in range(1, n_steps + 1)]]

lookback = 7
shifted_df = prepare_dataframe_for_lstm(dataset, lookback)
print(shifted_df)
# Out:
#                   Close   Close(t-1)   Close(t-2)   Close(t-3)   Close(t-4)  \
# Date
# 2004-08-30    50.814533    52.876804    53.753517    52.802086    52.239197
# 2004-08-31    50.993862    50.814533    52.876804    53.753517    52.802086
# 2004-09-01    49.937820    50.993862    50.814533    52.876804    53.753517
# 2004-09-02    50.565468    49.937820    50.993862    50.814533    52.876804
# 2004-09-03    49.818268    50.565468    49.937820    50.993862    50.814533
# ...                 ...          ...          ...          ...          ...
# 2021-10-05  2723.540039  2675.300049  2729.250000  2665.310059  2690.419922
# 2021-10-06  2747.080078  2723.540039  2675.300049  2729.250000  2665.310059
# 2021-10-07  2783.709961  2747.080078  2723.540039  2675.300049  2729.250000
# 2021-10-08  2801.120117  2783.709961  2747.080078  2723.540039  2675.300049
# 2021-10-11  2776.949951  2801.120117  2783.709961  2747.080078  2723.540039
#
#              Close(t-5)   Close(t-6)   Close(t-7)
# Date
# 2004-08-30    54.495735    53.952770    49.982655
# 2004-08-31    52.239197    54.495735    53.952770
# 2004-09-01    52.802086    52.239197    54.495735
# 2004-09-02    53.753517    52.802086    52.239197
# 2004-09-03    52.876804    53.753517    52.802086
# ...                 ...          ...          ...
# 2021-10-05  2723.679932  2830.020020  2852.659912
# 2021-10-06  2690.419922  2723.679932  2830.020020
# 2021-10-07  2665.310059  2690.419922  2723.679932
# 2021-10-08  2729.250000  2665.310059  2690.419922
# 2021-10-11  2675.300049  2729.250000  2665.310059
#
# [4310 rows x 8 columns]

# %%
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np
# Out:
# array([[  50.81453323,   52.87680435,   53.75351715, ...,   54.49573517,
#           53.95277023,   49.98265457],
#        [  50.99386215,   50.81453323,   52.87680435, ...,   52.23919678,
#           54.49573517,   53.95277023],
#        [  49.93782043,   50.99386215,   50.81453323, ...,   52.80208588,
#           52.23919678,   54.49573517],
#        ...,
#        [2783.70996094, 2747.08007812, 2723.54003906, ..., 2665.31005859,
#         2690.41992188, 2723.67993164],
#        [2801.12011719, 2783.70996094, 2747.08007812, ..., 2729.25      ,
#         2665.31005859, 2690.41992188],
#        [2776.94995117, 2801.12011719, 2783.70996094, ..., 2675.30004883,
#         2729.25      , 2665.31005859]])

# %%
shifted_df_as_np.shape
# Out:
# (4310, 8)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)

shifted_df_as_np
# Out:
# array([[-0.99930502, -0.9978664 , -0.99725482, ..., -0.99673705,
#         -0.99711582, -0.99988533],
#        [-0.99917992, -0.99930502, -0.9978664 , ..., -0.99831119,
#         -0.99673705, -0.99711582],
#        [-0.9999166 , -0.99917992, -0.99930502, ..., -0.99791852,
#         -0.99831119, -0.99673705],
#        ...,
#        [ 0.90713002,  0.88157746,  0.86515621, ...,  0.82453567,
#          0.84205201,  0.86525379],
#        [ 0.91927514,  0.90713002,  0.88157746, ...,  0.86913941,
#          0.82453567,  0.84205201],
#        [ 0.90241432,  0.91927514,  0.90713002, ...,  0.83150457,
#          0.86913941,  0.82453567]])

# %%
X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

X.shape, y.shape
# Out:
# ((4310, 7), (4310,))

# %%
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[-0.99988533, -0.99711582, -0.99673705, ..., -0.99791852,
#         -0.99725482, -0.9978664 ],
#        [-0.99711582, -0.99673705, -0.99831119, ..., -0.99725482,
#         -0.9978664 , -0.99930502],
#        [-0.99673705, -0.99831119, -0.99791852, ..., -0.9978664 ,
#         -0.99930502, -0.99917992],
#        ...,
#        [ 0.86525379,  0.84205201,  0.82453567, ...,  0.83150457,
#          0.86515621,  0.88157746],
#        [ 0.84205201,  0.82453567,  0.86913941, ...,  0.86515621,
#          0.88157746,  0.90713002],
#        [ 0.82453567,  0.86913941,  0.83150457, ...,  0.88157746,
#          0.90713002,  0.91927514]])

# %%
split_index = int(len(X) * 0.95)

split_index
# Out:
# 4094

# %%
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4094, 7), (216, 7), (4094,), (216,))

# %%
X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4094, 7, 1), (216, 7, 1), (4094, 1), (216, 1))

# %%
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([4094, 7, 1]),
#  torch.Size([216, 7, 1]),
#  torch.Size([4094, 1]),
#  torch.Size([216, 1]))

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
train_dataset

# %%
batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 7, 1]) torch.Size([16, 1])

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                            batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(1, 4, 1)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
class StockPredictionTrainer:
    def __init__(self, model, train_loader, test_loader, num_epochs=10, learning_rate=0.001):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.num_epochs = num_epochs
        self.learning_rate = learning_rate
        self.loss_function = nn.MSELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        self.gradients = []
        self.mean_losses = []
        self.losses = []


    def run_training(self):
        for epoch in range(self.num_epochs):
            self.model.train(True)  # Set the model to training mode
            print(f'Epoch: {epoch + 1}')
            running_loss = 0.0
            gradients = []  # Store gradients for each epoch
            mean_losses =[]
            losses =[]
            for batch_index, batch in enumerate(self.train_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                output = self.model(x_batch)
                loss = self.loss_function(output, y_batch)
                running_loss += loss.item()

                self.optimizer.zero_grad()
                loss.backward()
                losses.append(loss.item())
                # Store gradients for each parameter in the model
                sum_gradients = 0
                number_parameters = 0

                for layers in self.model.lstm.all_weights:
                    for weights in layers:
                        sum_gradients += weights.sum()
                        number_parameters += torch.numel(weights)

                mean_grad = sum_gradients / number_parameters
                self.gradients.append([mean_grad.detach().numpy()])


                self.optimizer.step()

                if batch_index % 100 == 99:  # print every 100 batches
                    avg_loss_across_batches = running_loss / 100
                    print('Batch {0}, Loss: {1:.3f}'.format(batch_index + 1, avg_loss_across_batches))
                    running_loss = 0.0
            print()


            # Validation after each epoch
            self.model.train(False)  # Set the model to evaluation mode
            running_loss = 0.0

            for batch_index, batch in enumerate(self.test_loader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                with torch.no_grad():
                    output = self.model(x_batch)
                    loss = self.loss_function(output, y_batch)
                    running_loss += loss.item()

            avg_loss_across_batches = running_loss / len(self.test_loader)
            self.mean_losses.append(avg_loss_across_batches)
            self.losses.append(sum(losses)/len(losses))
            print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
            print('***************************************************')
            print()


    def calculate_mae(self, predictions, targets):
        return mean_absolute_error(targets, predictions)

    def calculate_and_print_mae(self, X_train, y_train, X_test, y_test):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        mae_train = self.calculate_mae(predicted_train, y_train.numpy())
        mae_test = self.calculate_mae(predicted_test, y_test.numpy())

        print(f'Mean Absolute Error in training: {mae_train}')
        print(f'Mean Absolute Error in testing: {mae_test}')

    def plot_predictions(self, X_train, y_train, X_test, y_test, lookback):
        with torch.no_grad():
            predicted_train = self.model(X_train.to(device)).to('cpu').numpy()
            predicted_test = self.model(X_test.to(device)).detach().cpu().numpy().flatten()

        train_predictions = dc(predicted_train[:, 0])
        test_predictions = dc(predicted_test)

        self.plot_results(y_train, train_predictions, "Training Set")
        self.plot_results(y_test, test_predictions, "Test Set")

    def plot_results(self, actual, predicted, title):
        dummies_actual = np.zeros((actual.shape[0], 1))
        dummies_actual[:, 0] = actual.flatten()
        actual_values = dc(dummies_actual[:, 0])

        dummies_predicted = np.zeros((predicted.shape[0], 1))
        dummies_predicted[:, 0] = predicted.flatten()
        predicted_values = dc(dummies_predicted[:, 0])

        plt.plot(actual_values, label='Actual Close')
        plt.plot(predicted_values, label='Predicted Close')
        plt.xlabel('Day')
        plt.ylabel('Close')
        plt.title(title)
        plt.legend()
        plt.show()


    def plot_gradients_losses(self):
        figure, axis = plt.subplots(1, 2,figsize=(15, 5))
        axis[0].plot(self.gradients)
        axis[0].set_title('Fit in training')
        axis[0].set_xlabel('Steps (Iterations)')
        axis[0].set_ylabel('Mean gradient value')
      # Plot validation vs. training loss
        axis[1].plot(self.mean_losses, label='Training Loss')
        axis[1].plot(self.losses, label='Validation Loss', color='orange')
        axis[1].set_title('Validation vs. Training Loss')
        axis[1].set_xlabel('Epochs')
        axis[1].set_ylabel('Loss value (mean)')
        axis[1].legend()

        plt.show()

# %%
learning_rate = 0.001
num_epochs=30

# %%
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.060
# Batch 200, Loss: 0.015
#
# Val Loss: 0.323
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.268
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.233
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.200
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.165
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.144
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.128
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.116
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.105
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.092
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.082
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.079
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.073
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.068
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.061
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.052
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.049
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.050
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.046
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.047
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.044
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006495139095932245
# Mean Absolute Error in testing: 0.1642197221517563

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Increasing Sequence Length

# %%
model = LSTM(1, 8, 1)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.351
# Batch 200, Loss: 0.025
#
# Val Loss: 0.341
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.291
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.268
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.251
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.235
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.220
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.202
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.188
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.171
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.154
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.141
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.130
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.124
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.119
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.115
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.112
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.107
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.104
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.100
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.094
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.090
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.085
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.083
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.078
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.081
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.074
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.070
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.068
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.007114178501069546
# Mean Absolute Error in testing: 0.20234562456607819

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Increasing Stack

# %%
model = LSTM(1, 8, 3)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 8, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.143
# Batch 200, Loss: 0.039
#
# Val Loss: 0.547
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.002
# Batch 200, Loss: 0.001
#
# Val Loss: 0.363
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.253
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.205
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.184
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.175
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.164
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.160
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.153
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.146
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.143
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.136
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.129
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.128
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.119
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.118
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.113
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.112
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.112
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.104
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.095
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.097
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.100
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.100
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.087
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.095
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.090
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.078
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.084
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.087
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.010744543746113777
# Mean Absolute Error in testing: 0.23602743446826935

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Lets try hyperparameters

# %%
learning_rate = 0.0001
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.748
# Batch 200, Loss: 0.678
#
# Val Loss: 0.322
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.557
# Batch 200, Loss: 0.501
#
# Val Loss: 0.431
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.397
# Batch 200, Loss: 0.339
#
# Val Loss: 0.563
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.246
# Batch 200, Loss: 0.185
#
# Val Loss: 0.726
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.112
# Batch 200, Loss: 0.081
#
# Val Loss: 0.882
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.057
# Batch 200, Loss: 0.053
#
# Val Loss: 0.913
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.048
# Batch 200, Loss: 0.048
#
# Val Loss: 0.851
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.043
# Batch 200, Loss: 0.041
#
# Val Loss: 0.768
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.038
# Batch 200, Loss: 0.034
#
# Val Loss: 0.674
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.031
# Batch 200, Loss: 0.025
#
# Val Loss: 0.573
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.017
#
# Val Loss: 0.473
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.012
# Batch 200, Loss: 0.009
#
# Val Loss: 0.389
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.004
# Batch 200, Loss: 0.003
#
# Val Loss: 0.331
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.301
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.288
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.281
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.276
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.271
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.266
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.261
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.256
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.001
#
# Val Loss: 0.249
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.000
#
# Val Loss: 0.245
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.001
# Batch 200, Loss: 0.000
#
# Val Loss: 0.240
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.233
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.001
#
# Val Loss: 0.230
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.223
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.218
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.214
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.209
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.013228503055870533
# Mean Absolute Error in testing: 0.40575411915779114

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Decreasing learning rate

# %%
learning_rate = 0.01
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)

# %%
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.041
# Batch 200, Loss: 0.000
#
# Val Loss: 0.134
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.109
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.096
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.086
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.075
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.066
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.059
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.052
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.044
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.039
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.037
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.036
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.032
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006396309472620487
# Mean Absolute Error in testing: 0.12633728981018066

# %%
my_trainer.plot_gradients_losses()

# %% [markdown]
# Some changes in batch

# %%
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
learning_rate = 0.01
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.131
#
# Val Loss: 0.297
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.001
#
# Val Loss: 0.250
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.214
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.187
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.172
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.160
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.156
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.147
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.143
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.132
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.132
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.126
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.118
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.115
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.111
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.106
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.101
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.095
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.091
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.088
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.081
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.079
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.077
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.075
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.071
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.067
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.059
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.058
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.058
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0050111981108784676
# Mean Absolute Error in testing: 0.18610087037086487

# %%
my_trainer.plot_gradients_losses()

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
learning_rate = 0.01
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
#
# Val Loss: 0.452
# ***************************************************
#
# Epoch: 2
#
# Val Loss: 0.380
# ***************************************************
#
# Epoch: 3
#
# Val Loss: 0.331
# ***************************************************
#
# Epoch: 4
#
# Val Loss: 0.277
# ***************************************************
#
# Epoch: 5
#
# Val Loss: 0.227
# ***************************************************
#
# Epoch: 6
#
# Val Loss: 0.184
# ***************************************************
#
# Epoch: 7
#
# Val Loss: 0.151
# ***************************************************
#
# Epoch: 8
#
# Val Loss: 0.133
# ***************************************************
#
# Epoch: 9
#
# Val Loss: 0.121
# ***************************************************
#
# Epoch: 10
#
# Val Loss: 0.115
# ***************************************************
#
# Epoch: 11
#
# Val Loss: 0.110
# ***************************************************
#
# Epoch: 12
#
# Val Loss: 0.104
# ***************************************************
#
# Epoch: 13
#
# Val Loss: 0.102
# ***************************************************
#
# Epoch: 14
#
# Val Loss: 0.099
# ***************************************************
#
# Epoch: 15
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 16
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 17
#
# Val Loss: 0.088
# ***************************************************
#
# Epoch: 18
#
# Val Loss: 0.089
# ***************************************************
#
# Epoch: 19
#
# Val Loss: 0.084
# ***************************************************
#
# Epoch: 20
#
# Val Loss: 0.083
# ***************************************************
#
# Epoch: 21
#
# Val Loss: 0.080
# ***************************************************
#
# Epoch: 22
#
# Val Loss: 0.075
# ***************************************************
#
# Epoch: 23
#
# Val Loss: 0.075
# ***************************************************
#
# Epoch: 24
#
# Val Loss: 0.071
# ***************************************************
#
# Epoch: 25
#
# Val Loss: 0.067
# ***************************************************
#
# Epoch: 26
#
# Val Loss: 0.066
# ***************************************************
#
# Epoch: 27
#
# Val Loss: 0.068
# ***************************************************
#
# Epoch: 28
#
# Val Loss: 0.061
# ***************************************************
#
# Epoch: 29
#
# Val Loss: 0.058
# ***************************************************
#
# Epoch: 30
#
# Val Loss: 0.059
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006915017496794462
# Mean Absolute Error in testing: 0.16412506997585297

# %%
my_trainer.plot_gradients_losses()

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
learning_rate = 0.001
model = LSTM(1, 20, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
#
# Val Loss: 0.703
# ***************************************************
#
# Epoch: 2
#
# Val Loss: 0.573
# ***************************************************
#
# Epoch: 3
#
# Val Loss: 0.446
# ***************************************************
#
# Epoch: 4
#
# Val Loss: 0.393
# ***************************************************
#
# Epoch: 5
#
# Val Loss: 0.377
# ***************************************************
#
# Epoch: 6
#
# Val Loss: 0.363
# ***************************************************
#
# Epoch: 7
#
# Val Loss: 0.348
# ***************************************************
#
# Epoch: 8
#
# Val Loss: 0.333
# ***************************************************
#
# Epoch: 9
#
# Val Loss: 0.316
# ***************************************************
#
# Epoch: 10
#
# Val Loss: 0.302
# ***************************************************
#
# Epoch: 11
#
# Val Loss: 0.286
# ***************************************************
#
# Epoch: 12
#
# Val Loss: 0.273
# ***************************************************
#
# Epoch: 13
#
# Val Loss: 0.261
# ***************************************************
#
# Epoch: 14
#
# Val Loss: 0.250
# ***************************************************
#
# Epoch: 15
#
# Val Loss: 0.239
# ***************************************************
#
# Epoch: 16
#
# Val Loss: 0.228
# ***************************************************
#
# Epoch: 17
#
# Val Loss: 0.221
# ***************************************************
#
# Epoch: 18
#
# Val Loss: 0.210
# ***************************************************
#
# Epoch: 19
#
# Val Loss: 0.201
# ***************************************************
#
# Epoch: 20
#
# Val Loss: 0.193
# ***************************************************
#
# Epoch: 21
#
# Val Loss: 0.186
# ***************************************************
#
# Epoch: 22
#
# Val Loss: 0.178
# ***************************************************
#
# Epoch: 23
#
# Val Loss: 0.169
# ***************************************************
#
# Epoch: 24
#
# Val Loss: 0.161
# ***************************************************
#
# Epoch: 25
#
# Val Loss: 0.153
# ***************************************************
#
# Epoch: 26
#
# Val Loss: 0.146
# ***************************************************
#
# Epoch: 27
#
# Val Loss: 0.139
# ***************************************************
#
# Epoch: 28
#
# Val Loss: 0.135
# ***************************************************
#
# Epoch: 29
#
# Val Loss: 0.127
# ***************************************************
#
# Epoch: 30
#
# Val Loss: 0.121
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.009511358104646206
# Mean Absolute Error in testing: 0.2737880349159241

# %%
my_trainer.plot_gradients_losses()

# %%
learning_rate = 0.001
model = LSTM(1, 50, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
#
# Val Loss: 0.883
# ***************************************************
#
# Epoch: 2
#
# Val Loss: 0.382
# ***************************************************
#
# Epoch: 3
#
# Val Loss: 0.299
# ***************************************************
#
# Epoch: 4
#
# Val Loss: 0.236
# ***************************************************
#
# Epoch: 5
#
# Val Loss: 0.173
# ***************************************************
#
# Epoch: 6
#
# Val Loss: 0.117
# ***************************************************
#
# Epoch: 7
#
# Val Loss: 0.088
# ***************************************************
#
# Epoch: 8
#
# Val Loss: 0.079
# ***************************************************
#
# Epoch: 9
#
# Val Loss: 0.073
# ***************************************************
#
# Epoch: 10
#
# Val Loss: 0.070
# ***************************************************
#
# Epoch: 11
#
# Val Loss: 0.068
# ***************************************************
#
# Epoch: 12
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 13
#
# Val Loss: 0.060
# ***************************************************
#
# Epoch: 14
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 15
#
# Val Loss: 0.054
# ***************************************************
#
# Epoch: 16
#
# Val Loss: 0.054
# ***************************************************
#
# Epoch: 17
#
# Val Loss: 0.052
# ***************************************************
#
# Epoch: 18
#
# Val Loss: 0.050
# ***************************************************
#
# Epoch: 19
#
# Val Loss: 0.047
# ***************************************************
#
# Epoch: 20
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 21
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 22
#
# Val Loss: 0.039
# ***************************************************
#
# Epoch: 23
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 24
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 25
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 26
#
# Val Loss: 0.031
# ***************************************************
#
# Epoch: 27
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 28
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 29
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 30
#
# Val Loss: 0.027
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.008121046237647533
# Mean Absolute Error in testing: 0.12095986306667328

# %%
my_trainer.plot_gradients_losses()

# %%
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
learning_rate = 0.001
num_epochs = 100
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.131
#
# Val Loss: 0.994
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.027
#
# Val Loss: 0.487
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.002
#
# Val Loss: 0.401
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.001
#
# Val Loss: 0.360
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.001
#
# Val Loss: 0.329
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.001
#
# Val Loss: 0.304
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.001
#
# Val Loss: 0.286
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.001
#
# Val Loss: 0.267
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.001
#
# Val Loss: 0.252
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.238
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.222
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.208
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.195
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.171
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.162
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.149
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.142
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.130
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.121
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.112
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.102
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.098
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.091
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.083
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.079
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.073
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.069
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.065
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.061
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.000
#
# Val Loss: 0.060
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.000
#
# Val Loss: 0.053
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.000
#
# Val Loss: 0.054
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.000
#
# Val Loss: 0.050
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.000
#
# Val Loss: 0.049
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.000
#
# Val Loss: 0.046
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.000
#
# Val Loss: 0.043
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.000
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.000
#
# Val Loss: 0.039
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.000
#
# Val Loss: 0.039
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.000
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.000
#
# Val Loss: 0.041
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.000
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.000
#
# Val Loss: 0.033
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.000
#
# Val Loss: 0.036
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.000
#
# Val Loss: 0.032
# ***************************************************
#
# Epoch: 51
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 52
# Batch 100, Loss: 0.000
#
# Val Loss: 0.031
# ***************************************************
#
# Epoch: 53
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 54
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 55
# Batch 100, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 56
# Batch 100, Loss: 0.000
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 57
# Batch 100, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 58
# Batch 100, Loss: 0.000
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 59
# Batch 100, Loss: 0.000
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 60
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 61
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 62
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 63
# Batch 100, Loss: 0.000
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 64
# Batch 100, Loss: 0.000
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 65
# Batch 100, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 66
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 67
# Batch 100, Loss: 0.000
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 68
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 69
# Batch 100, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 70
# Batch 100, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 71
# Batch 100, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 72
# Batch 100, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 73
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 74
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 75
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 76
# Batch 100, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 77
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 78
# Batch 100, Loss: 0.000
#
# Val Loss: 0.016
# ***************************************************
#
# Epoch: 79
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 80
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 81
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 82
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 83
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 84
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 85
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 86
# Batch 100, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 87
# Batch 100, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 88
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 89
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 90
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 91
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 92
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 93
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 94
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 95
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 96
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 97
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 98
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 99
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 100
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.005975010339170694
# Mean Absolute Error in testing: 0.06880404055118561

# %%
my_trainer.plot_gradients_losses()

# %%
learning_rate = 0.01
num_epochs = 60
model = LSTM(1, 8, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.030
#
# Val Loss: 0.393
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.001
#
# Val Loss: 0.188
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.124
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.107
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.083
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.073
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.067
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.058
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.043
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.041
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.036
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 51
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 52
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 53
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 54
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 55
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 56
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 57
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 58
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 59
# Batch 100, Loss: 0.000
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 60
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.004600014071911573
# Mean Absolute Error in testing: 0.050996456295251846

# %%
my_trainer.plot_gradients_losses()

# %%
learning_rate = 0.01
num_epochs = 60
model = LSTM(1, 10, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.051
#
# Val Loss: 0.330
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
#
# Val Loss: 0.212
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.165
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.148
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.140
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.128
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.120
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.105
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.094
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.092
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.082
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.074
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.071
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.064
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.053
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.046
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.048
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.036
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.033
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.000
#
# Val Loss: 0.014
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.000
#
# Val Loss: 0.009
# ***************************************************
#
# Epoch: 51
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 52
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 53
# Batch 100, Loss: 0.000
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 54
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 55
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 56
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 57
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 58
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 59
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 60
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006063760258257389
# Mean Absolute Error in testing: 0.04614429548382759

# %%
learning_rate = 0.01
num_epochs = 30
model = LSTM(1, 15, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.060
#
# Val Loss: 0.303
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
#
# Val Loss: 0.152
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.106
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.067
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.053
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.050
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.035
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.033
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.042
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.032
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0060545578598976135
# Mean Absolute Error in testing: 0.08532363176345825

# %%
learning_rate = 0.01
num_epochs = 30
model = LSTM(1, 13, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.027
#
# Val Loss: 0.209
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
#
# Val Loss: 0.089
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.065
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.055
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.051
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.043
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.031
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.031
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.0051224189810454845
# Mean Absolute Error in testing: 0.02393767610192299

# %%
learning_rate = 0.01
num_epochs = 50
model = LSTM(1, 13, 1)
model.to(device)
model
my_trainer = StockPredictionTrainer(model, train_loader, test_loader, num_epochs=num_epochs, learning_rate=learning_rate)
my_trainer.run_training()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.060
#
# Val Loss: 0.217
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
#
# Val Loss: 0.156
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
#
# Val Loss: 0.125
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
#
# Val Loss: 0.103
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
#
# Val Loss: 0.079
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
#
# Val Loss: 0.062
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
#
# Val Loss: 0.050
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
#
# Val Loss: 0.038
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
#
# Val Loss: 0.011
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
#
# Val Loss: 0.013
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.000
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.000
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.000
#
# Val Loss: 0.001
# ***************************************************

# %%
my_trainer.plot_predictions(X_train, y_train, X_test, y_test, lookback)

# %%
my_trainer.plot_gradients_losses()

# %%
my_trainer.calculate_and_print_mae(X_train, y_train, X_test, y_test)
# Out:
# Mean Absolute Error in training: 0.006631901022046804
# Mean Absolute Error in testing: 0.021310552954673767
